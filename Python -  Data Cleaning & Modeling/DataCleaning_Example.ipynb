# %%
import pandas as pd
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
glassdoorjobs = pd.read_csv('Glassdoor_Job_Postings.csv')
df = glassdoorjobs.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   company                      899 non-null    object
#  1   job_title                    900 non-null    object
#  2   company_rating               656 non-null    float64
#  3   job_description              888 non-null    object
#  4   location                     900 non-null    object
#  5   salary_avg_estimate          636 non-null    object
#  6   salary_estimate_payperiod    636 non-null    object
#  7   company_size                 774 non-null    object
#  8   company_founded              774 non-null    object
#  9   employment_type              774 non-null    object
#  10  industry                     774 non-null    object
#  11  sector                       774 non-null    object
#  12  revenue                      774 non-null    object
#  13  career_opportunities_rating  731 non-null    float64
#  14  comp_and_benefits_rating     731 non-null    float64
#  15  culture_and_values_rating    731 non-null    float64
#  16  senior_management_rating     731 non-null    float64
#  17  work_life_balance_rating     731 non-null    float64
# dtypes: float64(6), object(12)
# memory usage: 126.7+ KB

# %%
df.head(5)
# Out:
#                company                       job_title  company_rating  \
# 0                  ABB             Junior Data Analyst             4.0
# 1              Philips          Data Scientist - AI/ML             4.0
# 2                 HSBC              Data Science GSC’s             3.9
# 3    Facctum Solutions                    Data Analyst             NaN
# 4  JPMorgan Chase & Co  Data and Analytics - Associate             4.0
#
#                                      job_description   location  \
# 0  Junior Data Analyst\nTake your next career ste...  Bengaluru
# 1  Job Title\nData Scientist - AI/ML\nJob Descrip...  Bengaluru
# 2  Job description\nGraduate/ Post-graduate degre...  Bengaluru
# 3  Job Description\nExperience: 0 - 2 years in da...  Karnataka
# 4  JOB DESCRIPTION\n\nYou are a strategic thinker...      India
#
#   salary_avg_estimate salary_estimate_payperiod       company_size  \
# 0           ₹3,25,236                /yr (est.)   10000+ Employees
# 1                 NaN                       NaN   10000+ Employees
# 2                 NaN                       NaN   10000+ Employees
# 3                 NaN                       NaN  1 to 50 Employees
# 4                 NaN                       NaN   10000+ Employees
#
#   company_founded    employment_type                         industry  \
# 0            1883   Company - Public        Electronics Manufacturing
# 1            1891   Company - Public  Healthcare Services & Hospitals
# 2            1865   Company - Public                Banking & Lending
# 3              --  Company - Private                               --
# 4            1799   Company - Public                Banking & Lending
#
#           sector                   revenue  career_opportunities_rating  \
# 0  Manufacturing        $10+ billion (USD)                          3.7
# 1     Healthcare        $10+ billion (USD)                          3.8
# 2        Finance        $10+ billion (USD)                          3.6
# 3             --  Unknown / Non-Applicable                          NaN
# 4        Finance        $10+ billion (USD)                          4.0
#
#    comp_and_benefits_rating  culture_and_values_rating  \
# 0                       3.6                        4.0
# 1                       3.7                        4.0
# 2                       3.6                        3.8
# 3                       NaN                        NaN
# 4                       3.9                        3.9
#
#    senior_management_rating  work_life_balance_rating
# 0                       3.5                       3.9
# 1                       3.5                       4.0
# 2                       3.4                       3.7
# 3                       NaN                       NaN
# 4                       3.6                       3.7

# %% [markdown]
# ## Find nulls and 'Unknown' records

# %%
# to find records that are odd - worked through every column
df['work_life_balance_rating'].unique()
#df['company'].value_counts()
# Out:
# array([3.9, 4. , 3.7, nan, 4.6, 3.5, 3.8, 3.1, 3.2, 4.1, 2. , 3. , 3.4,
#        2.9, 4.3, 4.2, 1. , 3.6, 3.3, 4.4, 2.5, 2.2, 4.5, 2.8, 4.8, 4.9,
#        4.7, 2.4, 5. , 2.3, 2.7, 2.6, 1.8])

# %%
# Looking at percentage of nulls
nulls = df.isna().sum()
nulls[nulls > 0] / df.shape[0] * 100
# Out:
# company                         0.111111
# company_rating                 27.111111
# job_description                 1.333333
# salary_avg_estimate            29.333333
# salary_estimate_payperiod      29.333333
# company_size                   14.000000
# company_founded                14.000000
# employment_type                14.000000
# industry                       14.000000
# sector                         14.000000
# revenue                        14.000000
# career_opportunities_rating    18.777778
# comp_and_benefits_rating       18.777778
# culture_and_values_rating      18.777778
# senior_management_rating       18.777778
# work_life_balance_rating       18.777778
# dtype: float64

# %%
# replace nulls
def replaceNulls(column, value):
    df[column] = df[column].fillna(value)

replaceNulls('company', 'Unknown')
replaceNulls('company_rating', -99) # fill with -99 to stand out from other ratings, indicating there is no rating
replaceNulls('job_description', 'Unknown')
replaceNulls('salary_avg_estimate', 'Unknown')
replaceNulls('salary_estimate_payperiod', 'Unknown')
replaceNulls('company_size', 'Unknown')
replaceNulls('company_founded', '0000')
replaceNulls('employment_type', 'Unknown')
replaceNulls('industry', 'Unknown')
replaceNulls('sector', 'Unknown')
replaceNulls('revenue', 'Unknown / Non-Applicable') # to match what's already there in that column
replaceNulls('career_opportunities_rating', -99)
replaceNulls('comp_and_benefits_rating', -99)
replaceNulls('culture_and_values_rating', -99)
replaceNulls('senior_management_rating', -99)
replaceNulls('work_life_balance_rating', -99)

# %%
df.isna().sum()
# Out:
# company                        0
# job_title                      0
# company_rating                 0
# job_description                0
# location                       0
# salary_avg_estimate            0
# salary_estimate_payperiod      0
# company_size                   0
# company_founded                0
# employment_type                0
# industry                       0
# sector                         0
# revenue                        0
# career_opportunities_rating    0
# comp_and_benefits_rating       0
# culture_and_values_rating      0
# senior_management_rating       0
# work_life_balance_rating       0
# dtype: int64

# %% [markdown]
# ### Replace any anomalies
# During EDA, I noticed that some records had '--' instead of NaN or 'Unknown'

# %%
# to find columns with the '--'
def findValue(df, value):
    for column in df.columns:
        if (df[column].unique() == value).any():
            print(f'{column}')

findValue(df, '--')
# Out:
# company_founded
# industry
# sector

# %%
# change those records appropriately
df['company_founded'] = df['company_founded'].replace('--', '0000')
df['industry'] = df['industry'].replace('--', 'Unknown')
df['sector'] = df['sector'].replace('--', 'Unknown')

# %%
df
# Out:
#                         company                            job_title  \
# 0                           ABB                  Junior Data Analyst
# 1                       Philips               Data Scientist - AI/ML
# 2                          HSBC                   Data Science GSC’s
# 3             Facctum Solutions                         Data Analyst
# 4           JPMorgan Chase & Co       Data and Analytics - Associate
# ..                          ...                                  ...
# 895              Kpro Solutions             Analytics & Data Science
# 896  Athena Global Technologies                        Data Engineer
# 897                       Wesco       India-Bangalore: Data Engineer
# 898                     Course5                       Data Scientist
# 899                  Sanfoundry  Machine Learning Engineer - Fresher
#
#      company_rating                                    job_description  \
# 0               4.0  Junior Data Analyst\nTake your next career ste...
# 1               4.0  Job Title\nData Scientist - AI/ML\nJob Descrip...
# 2               3.9  Job description\nGraduate/ Post-graduate degre...
# 3             -99.0  Job Description\nExperience: 0 - 2 years in da...
# 4               4.0  JOB DESCRIPTION\n\nYou are a strategic thinker...
# ..              ...                                                ...
# 895             4.0  Experience & Qualification:\n\nMinimum of 9 ye...
# 896           -99.0  Immediate requirement for Data Engineer\nExper...
# 897             3.7  This person will work independently or with a ...
# 898             4.2  If you meet our position requirements and can ...
# 899           -99.0  Job Code: Machine-Learning-Fresher-24012\n\nLo...
#
#       location salary_avg_estimate salary_estimate_payperiod  \
# 0    Bengaluru           ₹3,25,236                /yr (est.)
# 1    Bengaluru             Unknown                   Unknown
# 2    Bengaluru             Unknown                   Unknown
# 3    Karnataka             Unknown                   Unknown
# 4        India             Unknown                   Unknown
# ..         ...                 ...                       ...
# 895  Bengaluru           ₹4,83,915                /yr (est.)
# 896  Hyderābād           ₹6,78,949                /yr (est.)
# 897  Bengaluru           ₹6,51,920                /yr (est.)
# 898  Bengaluru           ₹4,24,426                /yr (est.)
# 899  Hyderābād             Unknown                   Unknown
#
#                company_size company_founded    employment_type  \
# 0          10000+ Employees            1883   Company - Public
# 1          10000+ Employees            1891   Company - Public
# 2          10000+ Employees            1865   Company - Public
# 3         1 to 50 Employees            0000  Company - Private
# 4          10000+ Employees            1799   Company - Public
# ..                      ...             ...                ...
# 895       1 to 50 Employees            0000  Company - Private
# 896     51 to 200 Employees            0000  Company - Private
# 897        10000+ Employees            1922   Company - Public
# 898  1001 to 5000 Employees            2000  Company - Private
# 899       1 to 50 Employees            0000      Self-employed
#
#                             industry                   sector  \
# 0          Electronics Manufacturing            Manufacturing
# 1    Healthcare Services & Hospitals               Healthcare
# 2                  Banking & Lending                  Finance
# 3                            Unknown                  Unknown
# 4                  Banking & Lending                  Finance
# ..                               ...                      ...
# 895                          Unknown                  Unknown
# 896                          Unknown                  Unknown
# 897                        Wholesale       Retail & Wholesale
# 898              Business Consulting  Management & Consulting
# 899          Colleges & Universities                Education
#
#                         revenue  career_opportunities_rating  \
# 0            $10+ billion (USD)                          3.7
# 1            $10+ billion (USD)                          3.8
# 2            $10+ billion (USD)                          3.6
# 3      Unknown / Non-Applicable                        -99.0
# 4            $10+ billion (USD)                          4.0
# ..                          ...                          ...
# 895    Unknown / Non-Applicable                          4.0
# 896    Unknown / Non-Applicable                          4.2
# 897          $10+ billion (USD)                          3.5
# 898  $100 to $500 million (USD)                          4.3
# 899    Unknown / Non-Applicable                          4.5
#
#      comp_and_benefits_rating  culture_and_values_rating  \
# 0                         3.6                        4.0
# 1                         3.7                        4.0
# 2                         3.6                        3.8
# 3                       -99.0                      -99.0
# 4                         3.9                        3.9
# ..                        ...                        ...
# 895                       4.0                        4.0
# 896                       3.5                        4.0
# 897                       3.4                        3.6
# 898                       4.1                        4.3
# 899                       4.3                        4.6
#
#      senior_management_rating  work_life_balance_rating
# 0                         3.5                       3.9
# 1                         3.5                       4.0
# 2                         3.4                       3.7
# 3                       -99.0                     -99.0
# 4                         3.6                       3.7
# ..                        ...                       ...
# 895                       4.0                       4.0
# 896                       3.9                       3.9
# 897                       3.3                       3.8
# 898                       4.1                       4.2
# 899                       4.7                       4.6
#
# [900 rows x 18 columns]

# %% [markdown]
# ### Cast to appropriate data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   company                      900 non-null    object
#  1   job_title                    900 non-null    object
#  2   company_rating               900 non-null    float64
#  3   job_description              900 non-null    object
#  4   location                     900 non-null    object
#  5   salary_avg_estimate          900 non-null    object
#  6   salary_estimate_payperiod    900 non-null    object
#  7   company_size                 900 non-null    object
#  8   company_founded              900 non-null    object
#  9   employment_type              900 non-null    object
#  10  industry                     900 non-null    object
#  11  sector                       900 non-null    object
#  12  revenue                      900 non-null    object
#  13  career_opportunities_rating  900 non-null    float64
#  14  comp_and_benefits_rating     900 non-null    float64
#  15  culture_and_values_rating    900 non-null    float64
#  16  senior_management_rating     900 non-null    float64
#  17  work_life_balance_rating     900 non-null    float64
# dtypes: float64(6), object(12)
# memory usage: 126.7+ KB

# %%
df['company_founded'] = df['company_founded'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   company                      900 non-null    object
#  1   job_title                    900 non-null    object
#  2   company_rating               900 non-null    float64
#  3   job_description              900 non-null    object
#  4   location                     900 non-null    object
#  5   salary_avg_estimate          900 non-null    object
#  6   salary_estimate_payperiod    900 non-null    object
#  7   company_size                 900 non-null    object
#  8   company_founded              900 non-null    int32
#  9   employment_type              900 non-null    object
#  10  industry                     900 non-null    object
#  11  sector                       900 non-null    object
#  12  revenue                      900 non-null    object
#  13  career_opportunities_rating  900 non-null    float64
#  14  comp_and_benefits_rating     900 non-null    float64
#  15  culture_and_values_rating    900 non-null    float64
#  16  senior_management_rating     900 non-null    float64
#  17  work_life_balance_rating     900 non-null    float64
# dtypes: float64(6), int32(1), object(11)
# memory usage: 123.2+ KB

# %% [markdown]
# ### Check for duplicates and delete them

# %%
df[df.duplicated()]
# Out:
#                                  company                           job_title  \
# 481                        Medpace, Inc.  Data Coordinator - Core Laboratory
# 570                        Medpace, Inc.  Data Coordinator - Core Laboratory
# 600                              Sandvik                 Data Entry Operator
# 780  Macgence Technologies (OPC) PVT LTD        Internship (Data Annotation)
# 782                              Empower             Sr Analyst Data Science
#
#      company_rating                                    job_description  \
# 481             3.4  Job Summary :\nOur corporate activities are gr...
# 570             3.4  Job Summary :\nOur corporate activities are gr...
# 600             4.2  Sandvik Mining & Rock Solutions, the leading g...
# 780             4.8  Selected intern's day-to-day responsibilities ...
# 782             3.9  Grow your career with a growing organization\n...
#
#       location salary_avg_estimate salary_estimate_payperiod  \
# 481      Thāne           ₹5,89,237                /yr (est.)
# 570      Thāne           ₹5,89,237                /yr (est.)
# 600    Udaipur           ₹4,15,692                /yr (est.)
# 780     Remote              ₹5,000                /mo (est.)
# 782  Bengaluru           ₹3,94,308                /yr (est.)
#
#                 company_size  company_founded    employment_type  \
# 481  5001 to 10000 Employees             1992   Company - Public
# 570  5001 to 10000 Employees             1992   Company - Public
# 600         10000+ Employees             1862   Company - Public
# 780                  Unknown                0   Company - Public
# 782         10000+ Employees             1907  Company - Private
#
#                           industry                          sector  \
# 481      Biotech & Pharmaceuticals  Pharmaceutical & Biotechnology
# 570      Biotech & Pharmaceuticals  Pharmaceutical & Biotechnology
# 600        Machinery Manufacturing                   Manufacturing
# 780                        Unknown                         Unknown
# 782  Investment & Asset Management                         Finance
#
#                       revenue  career_opportunities_rating  \
# 481    $2 to $5 billion (USD)                          3.3
# 570    $2 to $5 billion (USD)                          3.3
# 600        $10+ billion (USD)                          3.8
# 780  Unknown / Non-Applicable                          5.0
# 782    $2 to $5 billion (USD)                          3.9
#
#      comp_and_benefits_rating  culture_and_values_rating  \
# 481                       3.0                        3.2
# 570                       3.0                        3.2
# 600                       3.9                        4.0
# 780                       5.0                        5.0
# 782                       3.6                        3.9
#
#      senior_management_rating  work_life_balance_rating
# 481                       3.0                       3.2
# 570                       3.0                       3.2
# 600                       3.5                       3.9
# 780                       5.0                       5.0
# 782                       3.6                       4.0

# %%
df[df['company'] == 'Medpace, Inc.']
df = df.drop(index=[570, 481])
df.shape
# Out:
# (898, 18)

# %%
df[df['company'] == 'Sandvik']
df = df.drop(index=[480, 600])
df.shape
# Out:
# (896, 18)

# %%
df[df['company'] == 'Macgence Technologies (OPC) PVT LTD']
df = df.drop(index=780)
df
# Out:
#                         company                            job_title  \
# 0                           ABB                  Junior Data Analyst
# 1                       Philips               Data Scientist - AI/ML
# 2                          HSBC                   Data Science GSC’s
# 3             Facctum Solutions                         Data Analyst
# 4           JPMorgan Chase & Co       Data and Analytics - Associate
# ..                          ...                                  ...
# 895              Kpro Solutions             Analytics & Data Science
# 896  Athena Global Technologies                        Data Engineer
# 897                       Wesco       India-Bangalore: Data Engineer
# 898                     Course5                       Data Scientist
# 899                  Sanfoundry  Machine Learning Engineer - Fresher
#
#      company_rating                                    job_description  \
# 0               4.0  Junior Data Analyst\nTake your next career ste...
# 1               4.0  Job Title\nData Scientist - AI/ML\nJob Descrip...
# 2               3.9  Job description\nGraduate/ Post-graduate degre...
# 3             -99.0  Job Description\nExperience: 0 - 2 years in da...
# 4               4.0  JOB DESCRIPTION\n\nYou are a strategic thinker...
# ..              ...                                                ...
# 895             4.0  Experience & Qualification:\n\nMinimum of 9 ye...
# 896           -99.0  Immediate requirement for Data Engineer\nExper...
# 897             3.7  This person will work independently or with a ...
# 898             4.2  If you meet our position requirements and can ...
# 899           -99.0  Job Code: Machine-Learning-Fresher-24012\n\nLo...
#
#       location salary_avg_estimate salary_estimate_payperiod  \
# 0    Bengaluru           ₹3,25,236                /yr (est.)
# 1    Bengaluru             Unknown                   Unknown
# 2    Bengaluru             Unknown                   Unknown
# 3    Karnataka             Unknown                   Unknown
# 4        India             Unknown                   Unknown
# ..         ...                 ...                       ...
# 895  Bengaluru           ₹4,83,915                /yr (est.)
# 896  Hyderābād           ₹6,78,949                /yr (est.)
# 897  Bengaluru           ₹6,51,920                /yr (est.)
# 898  Bengaluru           ₹4,24,426                /yr (est.)
# 899  Hyderābād             Unknown                   Unknown
#
#                company_size  company_founded    employment_type  \
# 0          10000+ Employees             1883   Company - Public
# 1          10000+ Employees             1891   Company - Public
# 2          10000+ Employees             1865   Company - Public
# 3         1 to 50 Employees                0  Company - Private
# 4          10000+ Employees             1799   Company - Public
# ..                      ...              ...                ...
# 895       1 to 50 Employees                0  Company - Private
# 896     51 to 200 Employees                0  Company - Private
# 897        10000+ Employees             1922   Company - Public
# 898  1001 to 5000 Employees             2000  Company - Private
# 899       1 to 50 Employees                0      Self-employed
#
#                             industry                   sector  \
# 0          Electronics Manufacturing            Manufacturing
# 1    Healthcare Services & Hospitals               Healthcare
# 2                  Banking & Lending                  Finance
# 3                            Unknown                  Unknown
# 4                  Banking & Lending                  Finance
# ..                               ...                      ...
# 895                          Unknown                  Unknown
# 896                          Unknown                  Unknown
# 897                        Wholesale       Retail & Wholesale
# 898              Business Consulting  Management & Consulting
# 899          Colleges & Universities                Education
#
#                         revenue  career_opportunities_rating  \
# 0            $10+ billion (USD)                          3.7
# 1            $10+ billion (USD)                          3.8
# 2            $10+ billion (USD)                          3.6
# 3      Unknown / Non-Applicable                        -99.0
# 4            $10+ billion (USD)                          4.0
# ..                          ...                          ...
# 895    Unknown / Non-Applicable                          4.0
# 896    Unknown / Non-Applicable                          4.2
# 897          $10+ billion (USD)                          3.5
# 898  $100 to $500 million (USD)                          4.3
# 899    Unknown / Non-Applicable                          4.5
#
#      comp_and_benefits_rating  culture_and_values_rating  \
# 0                         3.6                        4.0
# 1                         3.7                        4.0
# 2                         3.6                        3.8
# 3                       -99.0                      -99.0
# 4                         3.9                        3.9
# ..                        ...                        ...
# 895                       4.0                        4.0
# 896                       3.5                        4.0
# 897                       3.4                        3.6
# 898                       4.1                        4.3
# 899                       4.3                        4.6
#
#      senior_management_rating  work_life_balance_rating
# 0                         3.5                       3.9
# 1                         3.5                       4.0
# 2                         3.4                       3.7
# 3                       -99.0                     -99.0
# 4                         3.6                       3.7
# ..                        ...                       ...
# 895                       4.0                       4.0
# 896                       3.9                       3.9
# 897                       3.3                       3.8
# 898                       4.1                       4.2
# 899                       4.7                       4.6
#
# [895 rows x 18 columns]

# %%
df[df['company'] == 'Empower']
df = df.drop(index=782)
df.shape
# Out:
# (894, 18)

# %% [markdown]
# Now the data cleaned up! Nulls are filled, duplicates are removed and any anomalies were replaced appropriately for consistency with unknown values.
